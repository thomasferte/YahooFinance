# %%
import os

# %%
os.getcwd()
os.chdir("../")
os.getcwd()
# Out:
# '/home/thomas/Documents/loisir/finance/YahooFinance'

# %%
from functions.plot_yfinance import plot_yfinance

# %%
plot_yfinance("aapl","max")
